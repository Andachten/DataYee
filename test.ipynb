# %%
from src import loadjpk  
ljp = loadjpk.loadjpkfile(r"D:\temp_data")
ljp[0]
# Out:
# {'tasktype': '',
#  'rawdata': {'extend': array([[(1.14420707e-05, -2.28349178e-10)],
#          [(1.14419373e-05, -2.34660123e-10)],
#          [(1.14417588e-05, -2.10184120e-10)],
#          [(1.14414186e-05, -2.31957861e-10)],
#          [(1.14412025e-05, -2.13692310e-10)],
#          [(1.14408173e-05, -2.40196249e-10)],
#          [(1.14404659e-05, -2.10171043e-10)],
#          [(1.14401257e-05, -2.04295239e-10)],
#          [(1.14396691e-05, -1.96941191e-10)],
#          [(1.14392726e-05, -2.02282367e-10)],
#          [(1.14387746e-05, -2.21736754e-10)],
#          [(1.14383424e-05, -2.14581680e-10)],
#          [(1.14378707e-05, -2.16832707e-10)],
#          [(1.14373652e-05, -2.09805260e-10)],
#          [(1.14368935e-05, -2.42539746e-10)],
#          [(1.14363936e-05, -2.20481602e-10)],
#          [(1.14359652e-05, -2.06267923e-10)],
#          [(1.14353996e-05, -1.96132220e-10)],
#          [(1.14349955e-05, -2.20552948e-10)],
#          [(1.14344374e-05, -2.11690504e-10)],
# ...

# %%
from pathlib import Path
import json
name_lst = [fname.stem.replace("fold_","").upper() for fname in Path(r"D:\Project\AlphaVirus\Binder_design\structure").glob("*zip")]
with open(r"D:\Project\AlphaVirus\Binder_design\structure\server/AlphaVirus.json",'r') as f:
    data = json.load(f)
[x['name'] for x in data if x['name'] not in name_lst]
# Out:
# []
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
